# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
import pandas as pd

df_alaska = pd.read_csv('alaska-pipeline.csv')
df_alaska.head()
# Out:
#    In-field-defect  In-lab-defect  Batch
# 0               18           20.2      1
# 1               38           56.0      1
# 2               15           12.5      1
# 3               20           21.2      1
# 4               18           15.5      1

# %%
df_alaska.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   In-field-defect  107 non-null    int64
#  1   In-lab-defect    107 non-null    float64
#  2   Batch            107 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 2.6 KB

# %%
df_alaska.isnull().sum()
# Out:
# In-field-defect    0
# In-lab-defect      0
# Batch              0
# dtype: int64

# %%
sns.pairplot(df_alaska)

# %%
sns.scatterplot(data=df_alaska, x='In-field-defect', y='In-lab-defect', hue='Batch')
# Out:
# <Axes: xlabel='In-field-defect', ylabel='In-lab-defect'>

# %%
df_alaska.describe()
# Out:
#        In-field-defect  In-lab-defect       Batch
# count       107.000000     107.000000  107.000000
# mean         33.579439      39.099065    3.233645
# std          18.600080      24.056398    1.557571
# min           5.000000       4.300000    1.000000
# 25%          18.000000      18.350000    2.000000
# 50%          35.000000      38.000000    3.000000
# 75%          46.500000      55.550000    5.000000
# max          85.000000      81.900000    6.000000

# %%
import pandas

df = pandas.read_csv("grades.csv")

print(df)
# Out:
#         name  quiz1  quiz2  quiz3    avg   min   max  range    std  pass
# 0    Matthew     85     93     79  85.67  79.0  93.0   14.0  27.73  pass
# 1       Leah     79     77     96  84.00  77.0  96.0   19.0  26.21  pass
# 2     Daniel     71     92     84  82.33  71.0  92.0   21.0  24.63  pass
# 3       Chad     75     91     89  85.00  75.0  91.0   16.0  26.73  pass
# 4        Tom     81     94     67  80.67  67.0  94.0   27.0  23.07  pass
# 5    Charles     94     89     96  93.00  89.0  96.0    7.0  32.57  pass
# 6      Tammy     97     88     95  93.33  88.0  97.0    9.0  31.99  pass
# 7        Amy     85     71     97  84.33  71.0  97.0   26.0  24.43  pass
# 8   Victoria     70     85     93  82.67  70.0  93.0   23.0  24.33  pass
# 9       Lisa     54     97     96  82.33  54.0  97.0   43.0  23.69  pass
# 10    Jeremy     89     77     81  82.33  77.0  89.0   12.0  27.12  pass
# 11     David     85     62     99  82.00  62.0  99.0   37.0  22.67  pass
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
import pandas as pd

df_sports = pd.read_csv('sports_class.csv')
df_sports.head()
# Out:
#    height  speed       sport
# 0     5.5     16      Soccer
# 1     5.8     18      Soccer
# 2     6.0     19      Soccer
# 3     5.0     17      Soccer
# 4     7.2     10  Basketball

# %%
df_sports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  12 non-null     float64
#  1   speed   12 non-null     int64
#  2   sport   12 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 420.0+ bytes

# %%
sns.pairplot(df_sports)

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("sports_class.csv")

print(df)
# Out:
#     height  speed       sport
# 0      5.5     16      Soccer
# 1      5.8     18      Soccer
# 2      6.0     19      Soccer
# 3      5.0     17      Soccer
# 4      7.2     10  Basketball
# 5      7.7      9  Basketball
# 6      6.9     11  Basketball
# 7      6.4     10  Basketball
# 8      4.1     12     Gymnast
# 9      4.4     13     Gymnast
# 10     4.8     12     Gymnast
# 11     4.9     13     Gymnast
